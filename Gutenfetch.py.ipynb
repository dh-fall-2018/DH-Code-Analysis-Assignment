# %%
import json
import zipfile
import os
import gutenberg
import pprint
import re

# %%
records = None
def load_data(fh=None):
    global records
    if records is not None:
        return
    records = list()
    if fh is None:
        fh = open('47000_metadata.json')
    for line in fh:
        records.append(json.loads(line))

def search(fn):
    if records is None:
        load_data()
    return [rec for rec in records if fn(rec)]

def pluck(exprs, rec):
    results = list()
    for item in exprs:
        if hasattr(item, '__call__'):
            results.append(item(rec))
        else:
            results.append(rec[item])
    return results

def get_iso_text(gutenberg_id, iso_path="/Volumes/PGDVD_2010_04_RC2"):
    import re, glob
    sid = str(gutenberg_id)
    path = '/'.join([iso_path] + list(sid[:-1]) + [sid])
    for fname in glob.glob(path + "/*.ZIP"):
        zf = zipfile.ZipFile(fname, 'r')
        txtfiles = [f for f in zf.infolist() \
                if re.search(r'\.txt$', f.filename, re.I)]
        if len(txtfiles) > 0:
            return zf.read(txtfiles[0].filename).decode('latin1')
    raise ValueError("couldn't fetch " + sid) 

def get_tar_text(gutenberg_id, tar_path="/gutenberg/files"):
    import glob
    sid = str(gutenberg_id)
    path = '/'.join([tar_path] + list(sid[:-1]) + [sid])
    fnames = sorted(glob.glob(path + "/%s*.txt" % sid), reverse=True)
    try:
        return gutenberg.GutenbergCleaner(open(fnames[0], encoding='latin1').read()).extract_text()
    except (ValueError, IndexError):
        raise

# %%
subjs = 'Fiction'
books = [pluck(['gutenberg_id', 'title'], r) for r in \
            search(lambda x: any([re.search(subjs, t['identifier'], re.I)
                for t in x['subjects']]))]
print(len(books))
pprint.pprint(books)
# Out:
# 13452
# [[15, 'Moby Dick; Or, The Whale'],
#  [16, 'Peter Pan in Kensington Gardens'],
#  [24, 'O Pioneers!'],
#  [27, 'Far from the Madding Crowd'],
#  [32, 'Herland'],
#  [33, 'The Scarlet Letter'],
#  [35, 'The Time Machine'],
#  [36, 'The War of the Worlds'],
#  [41, 'The Legend of Sleepy Hollow'],
#  [42, 'The Strange Case of Dr. Jekyll and Mr. Hyde'],
#  [43, 'The Strange Case of Dr. Jekyll and Mr. Hyde'],
#  [44, 'The Song of the Lark'],
#  [45, 'Anne of Green Gables'],
#  [46, 'A Christmas Carol in Prose; Being a Ghost Story of Christmas'],
#  [47, 'Anne of Avonlea'],
#  [51, 'Anne of the Island'],
#  [54, 'The Marvelous Land of Oz'],
#  [60, 'The Scarlet Pimpernel'],
#  [62, 'A Princess of Mars'],
#  [63, 'The Number "e"'],
#  [64, 'The Gods of Mars'],
#  [68, 'Warlord of Mars'],
#  [72, 'Thuvia, Maid of Mars'],
#  [73, 'The Red Badge of Courage: An Episode of the American Civil War'],
#  [74, 'The Adventures of Tom Sawyer'],
#  [76, "The Adventures of Huckleberry Finn (Tom Sawyer's Comrade)"],
#  [77, 'The House of the Seven Gables'],
#  [78, 'Tarzan of the Apes'],
#  [79, 'Terminal Compromise'],
#  [81, 'The Return of Tarzan'],
#  [82, 'Ivanhoe: A Romance'],
#  [84, 'Frankenstein; Or, The Modern Prometheus'],
#  [85, 'The Beasts of Tarzan'],
#  [86, "A Connecticut Yankee in King Arthur's Court"],
#  [90, 'The Son of Tarzan'],
#  [91, 'Tom Sawyer Abroad'],
#  [92, 'Tarzan and the Jewels of Opar'],
#  [93, 'Tom Sawyer, Detective'],
#  [94, "Alexander's Bridge"],
#  [95, 'The Prisoner of Zenda'],
#  [96, 'The Monster Men'],
#  [97, 'Flatland: A Romance of Many Dimensions'],
#  [98, 'A Tale of Two Cities'],
#  [101, 'The Hacker Crackdown: Law and Disorder on the Electronic Frontier'],
#  [102, "The Tragedy of Pudd'nhead Wilson"],
#  [103, 'Around the World in Eighty Days'],
#  [105, 'Persuasion'],
#  [106, 'Jungle Tales of Tarzan'],
#  [107, 'Far from the Madding Crowd'],
#  [108, 'The Return of Sherlock Holmes'],
#  [110, "Tess of the d'Urbervilles: A Pure Woman"],
#  [111, 'Freckles'],
#  [112, 'Violists'],
#  [113, 'The Secret Garden'],
#  [114, "The Tenniel Illustrations for Carroll's Alice in Wonderland"],
#  [119, 'A Tramp Abroad'],
#  [120, 'Treasure Island'],
#  [121, 'Northanger Abbey'],
#  [122, 'The Return of the Native'],
#  [123, "At the Earth's Core"],
#  [125, 'A Girl of the Limberlost'],
#  [126, 'The Poison Belt'],
#  [131, "The Pilgrim's Progress from this world to that which is to come"],
#  [133, 'The Damnation of Theron Ware'],
#  [134, 'Maria; Or, The Wrongs of Woman'],
#  [135, 'Les Misérables'],
#  [137, "Sara Crewe; Or, What Happened at Miss Minchin's Boarding School"],
#  [139, 'The Lost World'],
#  [140, 'The Jungle'],
#  [141, 'Mansfield Park'],
#  [142, 'The $30,000 Bequest, and Other Stories'],
#  [143, 'The Mayor of Casterbridge'],
#  [144, 'The Voyage Out'],
#  [145, 'Middlemarch'],
#  [146, 'A Little Princess'],
#  [149, 'The Lost Continent'],
#  [152, 'Wild Justice'],
#  [153, 'Jude the Obscure'],
#  [154, 'The Rise of Silas Lapham'],
#  [155, 'The Moonstone'],
#  [158, 'Emma'],
#  [159, 'The Island of Doctor Moreau'],
#  [160, 'The Awakening, and Selected Short Stories'],
#  [161, 'Sense and Sensibility'],
#  [163, 'Flower Fables'],
#  [164, 'Twenty Thousand Leagues Under the Sea'],
#  [165, 'McTeague: A Story of San Francisco'],
#  [166, 'Summer'],
#  [169, "The Well at the World's End: A Tale"],
#  [170, 'The Haunted Hotel: A Mystery of Modern Venice'],
#  [171, 'Charlotte Temple'],
#  [172, 'The Haunted Bookshop'],
#  [173, 'The Insidious Dr. Fu Manchu'],
#  [174, 'The Picture of Dorian Gray'],
#  [175, 'The Phantom of the Opera'],
#  [176, 'Roderick Hudson'],
#  [177, 'The American'],
#  [178, 'Confidence'],
#  [179, 'The Europeans'],
#  [201, 'Flatland: A Romance of Many Dimensions (Illustrated)'],
#  [203, "Uncle Tom's Cabin"],
#  [204, 'The Innocence of Father Brown'],
#  [208, 'Daisy Miller: A Study'],
#  [210, 'An International Episode'],
#  [211, 'The Aspern Papers'],
#  [215, 'Call of the Wild'],
#  [217, 'Sons and Lovers'],
#  [219, 'Heart of Darkness'],
#  [220, 'The Secret Sharer'],
#  [221, 'The Return of Sherlock Holmes'],
#  [222, 'The Moon and Sixpence'],
#  [223, 'The Wisdom of Father Brown'],
#  [224, 'A Pair of Blue Eyes'],
#  [233, 'Sister Carrie'],
#  [234, 'Child Christopher and Goldilind the Fair'],
#  [236, 'The Jungle Book'],
#  [238, 'Dear Enemy'],
#  [240, 'Stories from the Old Attic'],
#  [241,
#   'Clotelle; Or, The Colored Heroine, a tale of the Southern States; Or, The '
#   "President's Daughter"],
#  [242, 'My Antonia'],
#  [243, 'The Forged Coupon, and Other Stories'],
#  [244, 'A Study in Scarlet'],
#  [267, 'The Touchstone'],
#  [268, 'The Octopus : A Story of California'],
#  [269, 'Beasts and Super-Beasts'],
#  [271, 'Black Beauty - The Autobiography of a Horse'],
#  [283, 'The Reef'],
#  [284, 'The House of Mirth'],
#  [285, 'The Lost Continent'],
#  [286, 'Laddie: A True Blue Story'],
#  [287, 'Remember the Alamo'],
#  [288, 'The Certain Hour (Dizain des Poëtes)'],
#  [289, 'The Wind in the Willows'],
#  [290, 'The Stark Munro Letters'],
#  [291, 'The Golden Age'],
#  [292, 'Beauty and the Beast, and Tales of Home'],
#  [293, "Paul Prescott's Charge"],
#  [294, 'The Captain of the Polestar, and Other Tales'],
#  [295, 'The Early Short Fiction of Edith Wharton — Part 1'],
#  [296, 'The Cash Boy'],
#  [297, 'The Flirt'],
#  [298, 'The Market-Place'],
#  [299, 'Tales from Two Hemispheres'],
#  [305, "The Count's Millions"],
#  [306, 'The Early Short Fiction of Edith Wharton — Part 2'],
#  [307, 'Three Elephant Power, and Other Stories'],
#  [308, 'Three Men in a Boat (To Say Nothing of the Dog)'],
#  [310, 'Before Adam'],
#  [311, 'Bunner Sisters'],
#  [316, 'The Golden Road'],
#  [320, 'Vida De Lazarillo De Tormes Y De Sus Fortunas Y Adversidades'],
#  [321, 'Moran of the Lady Letty'],
#  [322, 'St. Ives: Being the Adventures of a French Prisoner in England'],
#  [324, 'A Knight of the Cumberland'],
#  [325, 'Phantastes: A Faerie Romance for Men and Women'],
#  [327, 'The Princess Aline'],
#  [329, "Island Nights' Entertainments"],
#  [330, "Where There's a Will"],
#  [332, 'The Burial of the Guns'],
#  [334, "Episodes in Van Bibber's Life"],
#  [335, 'Frances Waldeaux: A Novel'],
#  [339, 'Old Indian Days'],
#  [343, 'Fables'],
#  [344, 'The Merry Men, and Other Tales and Fables'],
#  [346, 'The Troll Garden, and Selected Stories'],
#  [347, "The Saga of Grettir the Strong: Grettir's Saga"],
#  [349, 'The Harvester'],
#  [350, 'Fanny Herself'],
#  [351, 'Of Human Bondage'],
#  [352, 'Buttered Side Down: Stories'],
#  [355, 'The Parasite'],
#  [356, 'Beyond the City'],
#  [357, "A Dream of John Ball; and, A King's Lesson"],
#  [358, 'The Scarlet Car'],
#  [361, 'Miss Billy'],
#  [362, 'Miss Billy'],
#  [364, 'The Mad King'],
#  [366, 'Bab: A Sub-Deb'],
#  [367, 'Country of the Pointed Firs'],
#  [369, 'The Outlaw of Torn'],
#  [370, 'The Fortunes and Misfortunes of the Famous Moll Flanders'],
#  [372, 'Prince Otto, a Romance'],
#  [375, 'An Occurrence at Owl Creek Bridge'],
#  [376, 'A Journal of the Plague Year'],
#  [378, 'The White Knight: Tirant Lo Blanc'],
#  [380, 'Weir of Hermiston: An Unfinished Romance'],
#  [384, 'The Lost Prince'],
#  [385, 'The Redheaded Outfield, and Other Baseball Stories'],
#  [388, 'The Crossing'],
#  [389, 'The Great God Pan'],
#  [393, 'The Blue Lagoon: A Romance'],
#  [394, 'Cranford'],
#  [395,
#   'The Holy War, Made by King Shaddai Upon Diabolus, for the Regaining of the '
#   'Metropolis of the World; Or, The Losing and Taking Again of the Town of '
#   'Mansoul'],
#  [396, 'The Lady, or the Tiger?'],
#  [399, 'Cast Upon the Breakers'],
#  [401, 'Blix'],
#  [402, 'Penrod'],
#  [407, 'The Reporter Who Made Himself King'],
#  [410, 'Hell Fer Sartain and Other Stories'],
#  [411, "The King's Jackal"],
#  [416, 'Winesburg, Ohio'],
#  [419, 'The Magic of Oz'],
#  [420, 'Dorothy and the Wizard in Oz'],
#  [421, 'Kidnapped'],
#  [422, 'The Romany Rye'],
#  [423, 'Round the Red Lamp'],
#  [426, 'Tales and Fantasies'],
#  [427, 'The Great War Syndicate'],
#  [428, 'Frivolous Cupid'],
#  [429, 'The Magic Egg, and Other Stories'],
#  [430, 'The Grain of Dust: A Novel'],
#  [431, 'The Fortune Hunter'],
#  [432, 'The Ambassadors'],
#  [433, 'The Conflict'],
#  [434, 'The Circular Staircase'],
#  [436,
#   'The Master Key, an Electrical Fairy Tale Founded Upon the Mysteries of '
#   'Electricity'],
#  [437,
#   'The Life of Lazarillo of Tormes: His Fortunes and Misfortunes as Told by '
#   'Himself'],
#  [440, 'Just David'],
#  [446, 'A Book of Remarkable Criminals'],
#  [447, 'Maggie, a Girl of the Streets'],
#  [450, 'Susan Lenox: Her Fall and Rise'],
#  [451, 'The Shadow Line'],
#  [452, 'Lavengro: The Scholar, The Gypsy, The Priest'],
#  [453, 'Emma McChesney and Co.'],
#  [456, 'The Door in the Wall and Other Stories'],
#  [457, 'The Price She Paid'],
#  [459, 'The White People'],
#  [460, 'The Dawn of a To-morrow'],
#  [461, 'The Quest of the Golden Girl: A Romance'],
#  [462, 'The Errand Boy; Or, How Phil Brent Won Success'],
#  [463, 'The Red Badge of Courage: An Episode of the American Civil War'],
#  [467, 'The Princess of Cleves'],
#  [468, 'Manon Lescaut'],
#  [469, 'The Duchesse of Langeais'],
#  [471, 'The Bride of Lammermoor'],
#  [472, 'The House Behind the Cedars'],
#  [477, 'Criminal Sociology'],
#  [478, 'The Cost'],
#  [479, 'Little Lord Fauntleroy'],
#  [480, '"Undo": A Novel'],
#  [481, "In the Bishop's Carriage"],
#  [482, 'The Woodlanders'],
#  [483, 'The Conquest of Canaan'],
#  [484,
#   'Poor and Proud; Or, The Fortunes of Katy Redburn: A Story for Young Folks'],
#  [485, 'The Road to Oz'],
#  [486, 'Ozma of Oz'],
#  [489, 'One Basket'],
#  [491, 'Rezanov'],
#  [493, 'Falk'],
#  [494, 'To-morrow'],
#  [495, 'Amy Foster'],
#  [498, 'Rebecca of Sunnybrook Farm'],
#  [499,
#   'Tom Swift in the Land of Wonders; Or, The Underground Search for the Idol '
#   'of Gold'],
#  [500, 'The Adventures of Pinocchio'],
#  [501, 'The Story of Doctor Dolittle'],
#  [502, 'Desert Gold'],
#  [504, 'The Fifth String'],
#  [506, 'The Shuttle'],
#  [507, 'Adam Bede'],
#  [508, 'Twice Told Tales'],
#  [509, 'The Purcell Papers — Volume 1'],
#  [510, 'The Purcell Papers — Volume 2'],
#  [511, 'The Purcell Papers — Volume 3'],
#  [512, 'Mosses from an Old Manse, and Other Stories'],
#  [515, 'Margret Howth: A Story of To-day'],
#  [517, 'The Emerald City of Oz'],
#  [518, 'The Enchanted Island of Yew'],
#  [519, 'A Kidnapped Santa Claus'],
#  [520, 'The Life and Adventures of Santa Claus'],
#  [521, 'The Life and Adventures of Robinson Crusoe'],
#  [524, 'Ann Veronica: A Modern Love Story'],
#  [526, 'Heart of Darkness'],
#  [527, 'The End of the Tether'],
#  [528, 'Joe the Hotel Boy; Or, Winning out by Pluck'],
#  [530, "Driven from Home; Or, Carl Crawford's Experience"],
#  [532, 'At the Foot of the Rainbow'],
#  [538, 'Jean of the Lazy A'],
#  [541, 'Age of Innocence'],
#  [543, 'Main Street'],
#  [544, "Anne's House of Dreams"],
#  [545, "At the Earth's Core"],
#  [546, 'Under the Andes'],
#  [547, "Baron Trigault's Vengeance"],
#  [549, 'The Underdogs: A Novel of the Mexican Revolution'],
#  [550, 'Silas Marner'],
#  [551, 'The Land That Time Forgot'],
#  [552, 'The People That Time Forgot'],
#  [553, "Out of Time's Abyss"],
#  [555, 'The Unbearable Bassington'],
#  [556, 'Rewards and Fairies'],
#  [557, "Puck of Pook's Hill"],
#  [558, 'The Thirty-Nine Steps'],
#  [559, 'Greenmantle'],
#  [560, 'Mr. Standfast'],
#  [561, 'The Further Adventures of Robinson Crusoe'],
#  [562, 'The Go Ahead Boys and the Racing Motor-Boat'],
#  [564, 'The Mystery of Edwin Drood'],
#  [572, 'Great Big Treasury of Beatrix Potter'],
#  [580, 'The Pickwick Papers'],
#  [581, "Ginx's Baby: His Birth and Other Misfortunes; a Satire"],
#  [582, 'A Collection of Beatrix Potter Stories'],
#  [583, 'The Woman in White'],
#  [584,
#   'Our Nig; Or, Sketches from the Life of a Free Black, in a Two-story White '
#   'House, North'],
#  [587, "Danny's Own Story"],
#  [588, "Master Humphrey's Clock"],
#  [589, 'Catriona'],
#  [593, 'A Selection from the Writings of Guy De Maupassant, Vol. I'],
#  [599, 'Vanity Fair'],
#  [600, 'Notes from the Underground'],
#  [601, 'The Monk: A Romance'],
#  [604, 'Gulliver of Mars'],
#  [605, 'Pellucidar'],
#  [611, 'Prester John'],
#  [619, 'The Warden'],
#  [624, 'Looking Backward: 2000-1887'],
#  [638, 'An Outcast of the Islands'],
#  [642, 'The Altar of the Dead'],
#  [643, 'The Death of the Lion'],
#  [645, 'The Figure in the Carpet'],
#  [646, 'The Coral Island'],
#  [647, 'The Dynamiter'],
#  [652, 'Rasselas, Prince of Abyssinia'],
#  [653, 'The Chimes'],
#  [659, 'Paul the Peddler; Or, The Fortunes of a Young Street Merchant'],
#  [671, 'Phil, the Fiddler'],
#  [676, 'The Battle of Life'],
#  [678, 'The Cricket on the Hearth'],
#  [681, 'Creatures That Once Were Men'],
#  [688, 'The Goodness of St. Rocque, and Other Stories'],
#  [689, 'The Kreutzer Sonata and Other Stories'],
#  [693, 'The Autobiography of a Quack, and The Case of George Dedlow'],
#  [694, "Stories from Everybody's Magazine"],
#  [696, 'The Castle of Otranto'],
#  [700, 'The Old Curiosity Shop'],
#  [702, "Somebody's Little Girl"],
#  [705, 'The Roadmender'],
#  [706, 'The Amateur Cracksman'],
#  [707, 'The Amateur Cracksman'],
#  [708, 'The Princess and the Goblin'],
#  [710, 'Love of Life, and Other Stories'],
#  [711, 'Allan Quatermain'],
#  [714, 'The Bobbsey Twins on Blueberry Island'],
#  [715, 'The Moon Endureth: Tales and Fancies'],
#  [716, 'The Cruise of the Jasper B.'],
#  [717, 'Chita: A Memory of Last Island'],
#  [718, 'Tono-Bungay'],
#  [720, "Almayer's Folly"],
#  [721, "The Birds' Christmas Carol"],
#  [726, 'A Psychological Counter-Current in Recent Fiction'],
#  [730, 'Oliver Twist'],
#  [737, 'The Bobbsey Twins on Blueberry Island'],
#  [746, 'Burning Daylight'],
#  [748, 'The Brother of Daphne'],
#  [751, 'The Autocrat of the Breakfast-Table'],
#  [753, 'Arizona Nights'],
#  [759, 'James Pethel'],
#  [761, 'A. V. Laider'],
#  [763,
#   "The Round-Up: A Romance of Arizona; Novelized from Edmund Day's Melodrama"],
#  [765, 'The Moon Pool'],
#  [767, 'Agnes Grey'],
#  [768, 'Wuthering Heights'],
#  [770, 'The Story of the Treasure Seekers'],
#  [773,
#   "Lord Arthur Savile's Crime; The Portrait of Mr. W.H., and Other Stories"],
#  [775, 'When the Sleeper Wakes'],
#  [776, 'Hermione and Her Little Group of Serious Thinkers'],
#  [778, 'Five Children and It'],
#  [780, 'The War in the Air'],
#  [783, 'The Lost City'],
#  [784,
#   'Boyhood in Norway: Stories of Boy-Life in the Land of the Midnight Sun'],
#  [786, 'Hard Times'],
#  [787, 'The Man Between: An International Romance'],
#  [788, 'The Red One'],
#  [789, 'The Gathering of Brother Hilarius'],
#  [792, 'Wieland; Or, The Transformation: An American Tale'],
#  [794,
#   'The Wouldbegoods: Being the Further Adventures of the Treasure Seekers'],
#  [796, 'La Chartreuse De Parme'],
#  [797, "L'Abbesse De Castro"],
#  [798, 'Le Rouge et le noir: chronique du XIXe siècle'],
#  [799, 'De la terre à la lune'],
#  [801, 'Les Cenci'],
#  [802, 'Vittoria Accoramboni'],
#  [803, 'La Duchesse De Palliano'],
#  [804, 'A Sentimental Journey Through France and Italy'],
#  [805, 'This Side of Paradise'],
#  [807, 'Hunted Down'],
#  [810, "George Silverman's Explanation"],
#  [821, 'Dombey and Son'],
#  [822, 'The Tarn of Eternity'],
#  [829, "Gulliver's Travels"],
#  [834, 'The Memoirs of Sherlock Holmes'],
#  [836, 'The Phoenix and the Carpet'],
#  [837, 'The Story of the Amulet'],
#  [839, 'New Arabian Nights'],
#  [840, 'Lorna Doone: A Romance of Exmoor'],
#  [842, 'Memoirs of Carwin the Biloquist (A Fragment)'],
#  [848, 'The Black Arrow: A Tale of the Two Roses'],
#  [850, 'Tom Grogan'],
#  [859, 'Polly of the Circus'],
#  [860, 'Baby Mine'],
#  [862, 'Philosophy 4: A Story of Harvard University'],
#  [863, 'The Mysterious Affair at Styles'],
#  [864, "The Master of Ballantrae: A Winter's Tale"],
#  [865, 'Passing of the Third Floor Back'],
#  [866, 'The Cost of Kindness'],
#  [867, 'Mrs. Korner Sins Her Mercies'],
#  [868, "The Philosopher's Joke"],
#  [869, 'The Soul of Nicholas Snyders; Or, The Miser of Zandam'],
#  [870, 'The Love of Ulrich Nebendahl'],
#  [872, 'Reprinted Pieces'],
#  [876, 'Life in the Iron-Mills; Or, The Korl Woman'],
#  [877, 'Little Britain'],
#  [881, 'Lemorne Versus Huell'],
#  [882, 'Sketches by Boz, illustrative of everyday life and every-day people'],
#  [883, 'Our Mutual Friend'],
#  [888, 'The Lazy Tour of Two Idle Apprentices'],
#  [898, 'The Lesson of the Master'],
#  [903, 'The White Company'],
#  [904, "Her Father's Daughter"],
#  [905, 'Within the Law: From the Play of Bayard Veiller'],
#  [910, 'White Fang'],
#  [911, 'Tales of the Fish Patrol'],
#  [912, 'Mudfog and Other Sketches'],
#  [913, 'A Hero of Our Time'],
#  [914, 'The Uncommercial Traveller'],
#  [917, 'Barnaby Rudge'],
#  [924, 'To Be Read at Dusk'],
#  [927, 'The Lamplighter'],
#  [936, 'The Village Watch-Tower'],
#  [938, 'Good Indian'],
#  [940, 'The Last of the Mohicans: A Narrative of 1757'],
#  [942, 'Green Mansions: A Romance of the Tropical Forest'],
#  [945, 'Dust'],
#  [946, 'Lady Susan'],
#  [949,
#   'Tom Swift and His Submarine Boat; Or, Under the Ocean for Sunken Treasure'],
#  [950,
#   'Tom Swift and His Electric Runabout; Or, The Speediest Car on the Road'],
#  [951, 'Tom Swift and His Sky Racer; Or, The Quickest Flight on Record'],
#  [952, 'Tom Swift and His Air Glider; Or, Seeking the Platinum Treasure'],
#  [953, 'Tom Swift and His Big Tunnel; Or, The Hidden City of the Andes'],
#  [954, 'Tom Swift and His War Tank; Or, Doing His Bit for Uncle Sam'],
#  [955, 'The Patchwork Girl of Oz'],
#  [956, 'Tik-Tok of Oz'],
#  [957, 'The Scarecrow of Oz'],
#  [958, 'Rinkitink in Oz'],
#  [959, 'The Lost Princess of Oz'],
#  [960, 'The Tin Woodman of Oz'],
#  [961, 'Glinda of Oz'],
#  [963, 'Little Dorrit'],
#  [965, 'The Black Tulip'],
#  [966, 'Maid Marian'],
#  [967, 'Nicholas Nickleby'],
#  [968, 'Martin Chuzzlewit'],
#  [969, 'The Tenant of Wildfell Hall'],
#  [973, "Howard Pyle's Book of Pirates"],
#  [974, 'The Secret Agent: A Simple Tale'],
#  [978, 'The Yates Pride: A Romance'],
#  [980, 'Alice Adams'],
#  [985, 'Father Sergius'],
#  [986, 'Master and Man'],
#  [993, 'Malbone: An Oldport Romance'],
#  [1013, 'The First Men in the Moon'],
#  [1014, 'The Lure of the Dim Trails'],
#  [1018, 'The Water-Babies'],
#  [1023, 'Bleak House'],
#  [1024, 'The Wrecker'],
#  [1026, 'The Diary of a Nobody'],
#  [1027, 'The Lone Star Ranger: A Romance of the Border'],
#  [1028, 'The Professor'],
#  [1029, 'The Night-Born'],
#  [1032, 'The Pupil'],
#  [1033, "Rose o' the River"],
#  [1036, 'Joe Wilson and His Mates'],
#  [1044, "Extract from Captain Stormfield's Visit to Heaven"],
#  [1047, 'The New Machiavelli'],
#  [1048, 'The Ruling Passion: Tales of Nature and Human Nature'],
#  [1051, 'Sartor Resartus: The Life and Opinions of Herr Teufelsdröckh'],
#  [1055, "'Twixt Land & Sea: Tales"],
#  [1056, 'Martin Eden'],
#  [1059, 'The World Set Free'],
#  [1063, 'The Cask of Amontillado'],
#  [1069, 'Four Short Stories By Emile Zola'],
#  [1074, 'The Sea-Wolf'],
#  [1075, 'The Strength of the Strong'],
#  [1076, 'The Wallet of Kai Lung'],
#  [1077, 'The Mirror of Kong Ho'],
#  [1078, 'The Scouts of the Valley'],
#  [1079, 'The Life and Opinions of Tristram Shandy, Gentleman'],
#  [1081, 'Dead Souls'],
#  [1083, 'The Arrow of Gold'],
#  [1086, "A Horse's Tale"],
#  [1087, 'Baartock'],
#  [1088, 'Rolf in the Woods'],
#  [1089, 'Moon-Face, and Other Stories'],
#  [1091,
#   'Sartor Resartus, and  On Heroes, Hero-Worship, and the Heroic in History'],
#  [1093, 'The Beast in the Jungle'],
#  [1095, 'The Light of the Western Stars'],
#  [1096, 'The Faith of Men'],
#  [1098, 'The Turmoil: A Novel'],
#  [1099, 'The Riverman'],
#  [1138, 'The Research Magnificent'],
#  [1144, 'In the Cage'],
#  [1145, 'Rupert of Hentzau: From The Memoirs of Fritz Von Tarlenheim'],
#  [1147, 'A Journey from This World to the Next'],
#  [1153, 'The Chessmen of Mars'],
#  [1154, 'The Voyages of Doctor Dolittle'],
#  [1155, 'The Secret Adversary'],
#  [1156, 'Babbitt'],
#  [1157, 'Damaged Goods'],
#  [1158, 'Penrod'],
#  [1159, 'Fire-Tongue'],
#  [1160, 'The Game'],
#  [1161, 'Jerry of the Islands'],
#  [1162, 'The Jacket (The Star-Rover)'],
#  [1163, 'Adventure'],
#  [1164, 'The Iron Heel'],
#  [1167, 'A Strange Disappearance'],
#  [1168, 'The Pool in the Desert'],
#  [1182, 'Dope'],
#  [1183, 'The Return of Dr. Fu-Manchu'],
#  [1184, 'The Count of Monte Cristo, Illustrated'],
#  [1188, 'The Lair of the White Worm'],
#  [1189, 'The Message'],
#  [1190, 'The Jolly Corner'],
#  [1193, 'The Coxon Fund'],
#  [1194, 'The Adventures of Louis de Rougemont'],
#  [1195, 'Glasses'],
#  [1196, 'The Purse'],
#  [1197, 'Taras Bulba, and Other Tales'],
#  [1198, 'Robbery under Arms'],
#  [1200, 'Gargantua and Pantagruel'],
#  [1203, 'Dolly Dialogues'],
#  [1204, 'Cabin Fever'],
#  [1206, 'The Flying U Ranch'],
#  [1207, 'Nada the Lily'],
#  [1208, 'South Sea Tales'],
#  [1210, 'Kwaidan: Stories and Studies of Strange Things'],
#  [1212, 'Love and Freindship [sic]'],
#  [1213, 'The Man That Corrupted Hadleyburg and Other Stories'],
#  [1214, 'The Street of Seven Stars'],
#  [1215, 'The Elixir of Life'],
#  [1217, "Penelope's Experiences in Scotland"],
#  [1218, 'The Adventures of Jimmie Dale'],
#  [1220, "The Atheist's Mass"],
#  [1223, 'Ursula'],
#  [1230, 'Pierre Grassou'],
#  [1231, 'On the Track'],
#  [1235, 'Captain Fracasse'],
#  [1237, 'Father Goriot'],
#  [1239,
#   'The Spirit of the Border: A Romance of the Early Settlers in the Ohio '
#   'Valley'],
#  [1242, 'Unconscious Comedians'],
#  [1245, 'Night and Day'],
#  [1249, 'Anthem'],
#  [1250, 'Anthem'],
#  [1253, 'A Simple Soul'],
#  [1257, 'The Three Musketeers'],
#  [1258, 'Ten Years Later'],
#  [1259, 'Twenty Years After'],
#  [1260, 'Jane Eyre'],
#  [1261, 'Betty Zane'],
#  [1262, 'The Heritage of the Desert: A Novel'],
#  [1263, 'The Glimpses of the Moon'],
#  [1264, 'The Wheels of Chance'],
#  [1266, 'Lavender and Old Lace'],
#  [1267, "Kai Lung's Golden Hours"],
#  [1268, 'The Mysterious Island'],
#  [1269, 'The Soul of a Bishop'],
#  [1273, 'The Autobiography of a Slander'],
#  [1274, "Martin Hyde, the Duke's Messenger"],
#  [1277, 'Melmoth Reconciled'],
#  [1278, "Penelope's English Experiences"],
#  [1281, 'Tom Swift and His Aerial Warship; Or, The Naval Terror of the Seas'],
#  [1282,
#   'Tom Swift Among the Diamond Makers; Or, The Secret of Phantom Mountain'],
#  [1283,
#   'Tom Swift and His Wizard Camera; Or, Thrilling Adventures While Taking '
#   'Moving Pictures'],
#  [1284, "Tom Swift and His Air Scout; Or, Uncle Sam's Mastery of the Sky"],
#  [1285, 'The Water Goats, and Other Troubles'],
#  [1289, 'Three Ghost Stories'],
#  [1290, 'Salammbo'],
#  [1291, 'Herodias'],
#  [1294, 'The Firm of Nucingen'],
#  [1296, 'The Provost'],
#  [1298, 'The Virginian: A Horseman of the Plains'],
#  [1299, 'The Heritage of the Sioux'],
#  [1300, 'Riders of the Purple Sage'],
#  [1303, 'The Scapegoat'],
#  [1305, 'The Ball at Sceaux'],
#  [1307, 'The Magic Skin'],
#  [1310, 'The Annals of the Parish'],
#  [1312, 'Selected Stories of Bret Harte'],
#  [1313, 'Over the Sliprails'],
#  [1314, 'The Malefactor'],
#  [1320,
#   'Criminal Psychology: A Manual for Judges, Practitioners, and Students'],
#  [1327, 'Elizabeth and Her German Garden'],
#  [1329, 'A Voyage to Arcturus'],
#  [1330, 'The Story of Little Black Mingo'],
#  [1332, 'Peter Pan in Kensington Gardens'],
#  [1334, 'Paul Kelver'],
#  [1343, 'Bureaucracy'],
#  [1344, 'The Secrets of the Princesse de Cadignan'],
#  [1345, 'The Vicar of Tours'],
#  [1348, "A Master's Degree"],
#  [1350, 'The Country Doctor'],
#  [1352, 'An Old Maid'],
#  [1353, 'Off on a Comet'],
#  [1354, 'Further Chronicles of Avonlea'],
#  [1355, 'The Underground City; Or, The Black Indies'],
#  [1356, 'The Cruise of the "Cachalot" Round the World After Sperm Whales'],
#  [1357, 'Madame Firmiani'],
#  [1359, 'A Guide to the Best Historical Novels and Tales'],
#  [1361, 'Tom Swift and His Giant Cannon; Or, The Longest Shots on Record'],
#  [1362,
#   'Tom Swift and His Undersea Search; Or, the Treasure on the Floor of the '
#   'Atlantic'],
#  [1363,
#   'Tom Swift Among the Fire Fighters; Or, Battling with Flames from the Air'],
#  [1364,
#   'Tom Swift and His Electric Locomotive; Or, Two Miles a Minute on the Rails'],
#  [1367, 'Findelkind'],
#  [1368, 'When the World Shook'],
#  [1369, 'Paz (La Fausse Maitresse)'],
#  [1373, 'Study of a Woman'],
#  [1374, 'Vendetta'],
#  [1375, 'New Chronicles of Rebecca'],
#  [1376, 'The Little White Bird; Or, Adventures in Kensington Gardens'],
#  [1377, 'The Talisman'],
#  [1380, 'The Two Brothers'],
#  [1384, 'The Ayrshire Legatees; Or, The Pringle Family'],
#  [1385, 'Lin McLean'],
#  [1386, 'Lady Baltimore'],
#  [1387, 'Mother'],
#  [1388, 'Padre Ignacio; Or, The Song of Temptation'],
#  [1389, 'Gobseck'],
#  [1390, 'The Jimmyjohn Boss, and Other Stories'],
#  [1391, "Penelope's Irish Experiences"],
#  [1396, 'Rienzi, the Last of the Roman Tribunes'],
#  [1399, 'Anna Karenina'],
#  [1400, 'Great Expectations'],
#  [1401, 'Tarzan the Untamed'],
#  [1402, 'Where the Blue Begins'],
#  [1403, 'A Start in Life'],
#  [1405, 'The Collection of Antiquities'],
#  [1406, 'Perils of Certain English Prisoners'],
#  [1407, 'A Message from the Sea'],
#  [1410, 'The Commission in Lunacy'],
#  [1411, 'Domestic Peace'],
#  [1412, 'Masterman Ready'],
#  [1413, "Tom Tiddler's Ground"],
#  [1414, "Somebody's Luggage"],
#  [1416, "Mrs. Lirriper's Lodgings"],
#  [1417, 'Sons of the Soil'],
#  [1419, 'Mugby Junction'],
#  [1420, "London's Underworld"],
#  [1421, "Mrs. Lirriper's Legacy"],
#  [1422, 'Going into Society'],
#  [1423, 'No Thoroughfare'],
#  [1424, 'Castle Rackrent'],
#  [1425, 'El Verdugo'],
#  [1426, 'The Recruit'],
#  [1427, 'A Drama on the Seashore'],
#  [1428, 'La Grenadiere'],
#  [1429, 'The Garden Party, and Other Stories'],
#  [1431, 'Trooper Peter Halket of Mashonaland'],
#  [1432, 'Seraphita'],
#  [1433, 'The Red Inn'],
#  [1437, 'Juana'],
#  [1438, 'No Name'],
#  [1439, 'Dreams'],
#  [1441, 'The Story of an African Farm'],
#  [1442, 'The Kingdom of the Blind'],
#  [1443, 'Two Poets'],
#  [1444, 'The Four Million'],
#  [1447, 'The Illustrious Prince'],
#  [1449, 'The Valley of the Moon'],
#  [1450, 'Pollyanna'],
#  [1453, 'The Alkahest'],
#  [1454, 'Maitre Cornelius'],
#  [1455, 'The Hated Son'],
#  [1456, 'An Episode under the Terror'],
#  [1457, 'Mistress Wilding'],
#  [1458, 'Dream Life and Real Life: A Little African Story'],
#  [1460, 'The Black Dwarf'],
#  [1461, 'A Legend of Montrose'],
#  [1463, 'The Private Papers of Henry Ryecroft'],
#  [1465, 'The Wreck of the Golden Mary'],
#  [1466, 'Creatures That Once Were Men'],
#  [1472, 'In a German Pension'],
#  [1473, 'The Absentee'],
#  [1474, 'The Illustrious Gaudissart'],
#  [1475, 'Gaudissart II'],
#  [1476, 'Chance: A Tale in Two Parts'],
#  [1480, "Tom Brown's School Days"],
#  [1481, 'A Daughter of Eve'],
#  [1482, 'Modeste Mignon'],
#  [1484, 'The Four Horsemen of the Apocalypse'],
#  [1495, 'The Golf Course Mystery'],
#  [1550, 'A Lady of Quality'],
#  [1551, 'A Cathedral Courtship'],
#  [1552,
#   'The Lock and Key Library: The Most Interesting Stories of All Nations: '
#   'North Europe — Russian — Swedish — Danish — Hungarian'],
#  [1553, 'The Hidden Masterpiece'],
#  [1554, 'Adieu'],
#  [1555, 'A Passion in the Desert'],
#  [1556, 'The Marriage Contract'],
#  [1557, 'Men of Iron'],
#  [1559, 'A Distinguished Provincial at Paris'],
#  [1563, 'The Crystal Stopper'],
#  [1565, 'The Last Days of Pompeii'],
#  [1569, 'The Lily of the Valley'],
#  [1573, "Frank's Campaign; Or, The Farm and the Camp"],
#  [1577, 'The Grey Room'],
#  [1583, 'Options'],
#  [1585, 'The Wrong Box'],
#  [1586, 'Man and Wife'],
#  [1587, 'The Black Robe'],
#  [1588, "A Rogue's Life"],
#  [1590, 'The Amazing Interlude'],
#  [1595, 'Whirligigs'],
#  [1596, 'Smoke Bellew'],
#  [1601, 'The Breaking Point'],
#  [1602, "Dawn O'Hara: The Girl Who Laughed"],
#  [1603, 'The Blue Flower'],
#  [1604, 'The Ebb-Tide: A Trio And Quartette'],
#  [1605, 'The Crock of Gold'],
#  [1606, 'Kenilworth'],
#  [1607, 'A Journey in Other Worlds: A Romance of the Future'],
#  [1608, 'Camille (La Dame aux Camilias)'],
#  [1611, 'Seventeen'],
#  [1613, 'Count Bunker'],
#  [1614, 'The Golden Fleece: A Romance'],
#  [1617, 'The Wind in the Rose-Bush, and Other Stories of the Supernatural'],
#  [1619, 'La Celestina'],
#  [1620, 'The Lion and the Unicorn'],
#  [1621, 'Miss or Mrs.?'],
#  [1622, 'The Law and the Lady'],
#  [1623, 'The New Magdalen'],
#  [1624, 'The Two Destinies'],
#  [1625, 'The Frozen Deep'],
#  [1626, 'After Dark'],
#  [1627, 'The Evil Genius: A Domestic Story'],
#  [1628, "My Lady's Money"],
#  [1629, '"I Say No"'],
#  [1630, 'Little Novels'],
#  [1631, 'A Monk of Fife'],
#  [1633, 'The Brick Moon, and Other Stories'],
#  [1634, 'The Foolish Virgin'],
#  [1639, 'Eve and David'],
#  [1640, 'Lilith: A Romance'],
#  [1641, 'The Lesser Bourgeoisie'],
#  [1644, 'The Adventures of Gerard'],
#  [1646, 'Roads of Destiny'],
#  [1649, 'Ferragus, Chief of the Dévorants'],
#  [1651, 'The Mystery of Orcival'],
#  [1652, 'The Survivors of the Chancellor: Diary of J.R. Kazallon, Passenger'],
#  [1654, 'An Unsocial Socialist'],
#  [1655, 'The God of His Fathers: Tales of the Klondyke'],
#  [1659, 'The Girl with the Golden Eyes'],
#  [1660, "Scenes from a Courtesan's Life"],
#  [1661, 'The Adventures of Sherlock Holmes'],
#  [1665, 'Derrick Vaughan, Novelist'],
#  [1666, 'The Golden Asse'],
#  [1667, "My Aunt Margaret's Mirror"],
#  [1668, "The Tapestried Chamber, and Death of the Laird's Jock"],
#  [1671, 'When a Man Marries'],
#  [1678, 'An Historical Mystery (The Gondreville Mystery)'],
#  [1679, 'Hiram the Young Farmer'],
#  [1680, 'At the Sign of the Cat and Racket'],
#  [1683, 'Honorine'],
#  [1684, 'The Egoist: A Comedy in Narrative'],
#  [1685, 'The Mystery of the Yellow Room'],
#  [1686, 'The Secret of the Night'],
#  [1690, 'Marie: An Episode in the Life of the Late Allan Quatermain'],
#  [1692, '1492'],
#  [1693, 'Dangerous Days'],
#  [1695, 'The Man Who was Thursday, A Nightmare'],
#  [1696, 'The Club of Queer Trades'],
#  [1698, 'The Survivors of the Chancellor'],
#  [1699, 'The Vanished Messenger'],
#  [1701, 'The Story of Waitstill Baxter'],
#  [1703, 'Dead Men Tell No Tales'],
#  [1704, 'Pierrette'],
#  [1709, 'New Grub Street'],
#  [1710, 'La Grande Breteche'],
#  [1711, 'Child of Storm'],
#  [1712, 'The Rescue'],
#  [1714, 'Another Study of Woman'],
#  [1715, 'Eugenie Grandet'],
#  [1716, 'The Copy-Cat, and Other Stories'],
#  [1718, 'Manalive'],
#  [1720, 'The Man Who Knew Too Much'],
#  [1721, 'The Trees of Pride'],
#  [1723, 'Cow-Country'],
#  [1724, 'Finished'],
#  [1725, 'Heart of the West [Annotated]'],
#  [1729, 'The Deserted Woman'],
#  [1730, 'Michael, Brother of Jerry'],
#  [1732, 'The Schoolmistress, and Other Stories'],
#  [1733, 'The Red Cross Girl'],
#  [1734, 'Secret Places of the Heart'],
#  [1737, 'Facino Cane'],
#  [1740, "The Flying U's Last Stand"],
#  [1741, 'The White Moll'],
#  [1743, 'Twelve Stories and a Dream'],
#  [1747, 'The Red Seal'],
#  [1748, "Other People's Money"],
#  [1749, 'Cousin Betty'],
#  [1752, 'The Scarlet Pimpernel'],
#  [1757, 'The Cruise of the Dolphin'],
#  [1758, 'Majorie Daw'],
#  [1760, 'The Man Who Could Not Lose'],
#  [1761, 'My Buried Treasure'],
#  [1762, 'The Consul'],
#  [1763, 'The Nature Faker'],
#  [1764, 'Billy and the Big Stick'],
#  [1803, 'Wyoming: A Story of the Outdoor West'],
#  [1805, 'The Gentle Grafter'],
#  [1806, 'The Frame Up'],
#  [1807, 'The Lost House'],
#  [1808, 'The Log of the "Jolly Polly"'],
#  [1809, "Bucky O'Connor: A Tale of the Unfenced Border"],
#  [1810, 'A Second Home'],
#  [1811, 'Massimilla Doni'],
#  [1812, 'A Prince of Bohemia'],
#  [1813, 'A Man of Business'],
#  [1814, 'The Agony Column'],
#  [1816, 'Tattine'],
#  [1817, 'A Question of Latitude'],
#  [1818, 'The Spy'],
#  [1819, 'The Messengers'],
#  [1820, 'A Wasted Day'],
#  [1821, 'A Charmed Life'],
#  [1822, 'The Amateur'],
#  [1823, 'The Make-Believe Man'],
#  [1824, 'Peace Manoeuvres'],
#  [1825, 'The Adventures of Reddy Fox'],
#  [1826, 'Sarrasine'],
#  [1828, 'Chronicles of the Canongate, 1st Series'],
#  [1829, 'Mae Madden'],
#  [1831,
#   'The Lock and Key Library: Classic Mystery and Detective Stories: Old Time '
#   'English'],
#  [1832, 'The Case of the Lamp That Went Out'],
#  [1833, 'The Case of the Registered Letter'],
#  [1834, 'The Case of the Pocket Diary Found in the Snow'],
#  [1835, "The Case of the Pool of Blood in the Pastor's Study"],
#  [1836, 'The Case of the Golden Bullet'],
#  [1837, 'The Prince and the Pauper'],
#  [1839, 'Other Things Being Equal'],
#  [1840, 'The Financier: A Novel'],
#  [1841, 'Z. Marcas'],
#  [1842, 'Michael Strogoff'],
#  [1843, 'Vera, the Medium'],
#  [1845, 'Zuleika Dobson; Or, An Oxford Love Story'],
#  [1846, 'The Vision Splendid'],
#  [1848, "Montezuma's Daughter"],
#  [1849, 'The Yellow Crayon'],
#  [1851, 'The Woman in the Alcove'],
#  [1853, 'The ninth vibration and other stories'],
#  [1854, 'Catherine De Medici'],
#  [1856, 'Cousin Pons'],
#  [1857, 'Initials Only'],
#  [1858, 'Plain Tales from the Hills'],
#  [1860,
#   'Westward Ho! Or, The Voyages and Adventures of Sir Amyas Leigh, Knight, of '
#   'Burrough, in the County of Devon, in the Reign of Her Most Glorious Majesty '
#   'Queen Elizabeth'],
#  [1862, 'Tartarin of Tarascon'],
#  [1867, 'The Diary of a Goose Girl'],
#  [1868, "Penelope's Postscripts"],
#  [1869, 'The Man in Lower Ten'],
#  [1870, 'Reginald in Russia, and Other Sketches'],
#  [1871, 'The Deputy of Arcis'],
#  [1872, 'The Red House Mystery'],
#  [1873, 'Gambara'],
#  [1874, 'The Railway Children'],
#  [1875, 'Painted Windows'],
#  [1876, 'The Shape of Fear'],
#  [1877, 'A Mountain Woman'],
#  [1878, 'A Millionaire of Yesterday'],
#  [1880, 'The Pathfinder; Or, The Inland Sea'],
#  [1881, 'The Call of the Canyon'],
#  [1882, 'The Young Forester'],
#  [1883, 'The Wife, and Other Stories'],
#  [1884, 'The Exiles'],
#  [1888, 'The Bittermeads Mystery'],
#  [1892, "Extracts from Adam's Diary"],
#  [1895, 'Armadale'],
#  [1897, 'The Seventh Man'],
#  [1898, 'Albert Savarus'],
#  [1899, 'The Village Rector'],
#  [1900, 'Typee: A Romance of the South Seas'],
#  [1902, 'The Old Peabody Pew: A Christmas Romance of a Country Church'],
#  [1904, 'The Life and Perambulations of a Mouse'],
#  [1905, 'The Governess; Or, The Little Female Academy'],
#  [1906, 'Erewhon; Or, Over the Range'],
#  [1907, 'Rowdy of the Cross L'],
#  [1908, 'Her Prairie Knight'],
#  [1910, 'La tulipe noire'],
#  [1912, 'The Muse of the Department'],
#  [1913, 'The Drums of Jeopardy'],
#  [1916, 'The Great Stone Face, and Other Tales of the White Mountains'],
#  [1917, 'The Queen of Hearts'],
#  [1918, 'Long Odds'],
#  [1920, "Billy Baxter's Letters"],
#  [1921, 'The Chouans'],
#  [1923, 'The Poisoned Pen'],
#  [1925, 'Droll Stories — Volume 1'],
#  [1927, 'Elinor Wyllys; Or, The Young Folk of Longbridge: A Tale. Volume 1'],
#  [1928, 'Elinor Wyllys; Or, The Young Folk of Longbridge: A Tale. Volume 2'],
#  [1930, 'Penguin Island'],
#  [1931, "The Zeppelin's Passenger"],
#  [1933, 'The History of Samuel Titmarsh and the Great Hoggarty Diamond'],
#  [1935, 'The Tremendous Adventures of Major Gahagan'],
#  [1937, 'The Second Jungle Book'],
#  [1938, 'Resurrection'],
#  [1939,
#   'A Gentleman of France: Being the Memoirs of Gaston de Bonne Sieur de '
#   'Marsac'],
#  [1940, 'Christ in Flanders'],
#  [1941, 'Letters of Two Brides'],
#  [1942, 'Rise and Fall of Cesar Birotteau'],
#  [1943, 'Louis Lambert'],
#  [1944, 'The Witch, and Other Stories'],
#  [1947, 'Scaramouche: A Romance of the French Revolution'],
#  [1948, 'The Story of a Bad Boy'],
#  [1950, 'A Woman of Thirty'],
#  [1951, 'The Coming Race'],
#  [1952, 'The Yellow Wallpaper'],
#  [1954, 'Colonel Chabert'],
#  [1957, 'Beatrix'],
#  [1960, 'Sight Unseen'],
#  [1963, 'The Confession'],
#  [1965, 'Captain Blood'],
#  [1966, 'The Path of the King'],
#  [1967, 'The Brotherhood of Consolation'],
#  [1968, 'The Human Comedy: Introductions and Appendix'],
#  [1969, 'Catherine: a Story'],
#  [1970, 'A Poor Wise Man'],
#  [1971,
#   'Erewhon Revisited Twenty Years Later, Both by the Original Discoverer of '
#   'the Country and by His Son'],
#  [1975, 'The Legacy of Cain'],
#  [1976, 'The Double Four'],
#  [1980, 'Stories by English Authors: Africa (Selected by Scribners)'],
#  [1981, 'Le droit de lire'],
#  [1982, '羅生門'],
#  [1983, 'Monsieur Beaucaire'],
#  [1985, "Men's Wives"],
#  [1986, 'Life and Death of Mr. Badman'],
#  [1987, 'The Outlet'],
#  [1990, 'The Bedford-Row Conspiracy'],
#  [1999, 'Crome Yellow'],
#  [2000, 'Don Quijote'],
#  [2005, 'Piccadilly Jim'],
#  [2006, 'A Fair Penitent'],
#  [2007, 'We Two: A Novel'],
#  [2011, 'Rudder Grange'],
#  [2014, 'The Lodger'],
#  [2020, 'Tarzan the Terrible'],
#  [2021, 'Nostromo'],
#  [2023, 'Malvina of Brittany'],
#  [2025, 'My Lady Caprice'],
#  [2026, 'The Coming Conquest of England'],
#  [2028, 'The Yellow Claw'],
#  [2029, 'Lahoma'],
#  [2031,
#   'The Lock and Key Library: The Most Interesting Stories of All Nations: Real '
#   'Life'],
#  [2032, 'Martin Pippin in the Apple Orchard'],
#  [2034, "Waverley; Or, 'Tis Sixty Years Since"],
#  [2035, 'Stories by English Authors: The Orient (Selected by Scribners)'],
#  [2037, 'Novel Notes'],
#  [2038,
#   'The Lock and Key Library: Classic Mystery and Detective Stories: Modern '
#   'English'],
#  [2040, 'Confessions of an English Opium-Eater'],
#  [2041, 'The House of the Wolf: A Romance'],
#  [2042, 'Something New'],
#  [2046, "Clotel; Or, The President's Daughter"],
#  [2048, 'The Sketch-Book of Geoffrey Crayon'],
#  [2051, "Dickory Cronke: The Dumb Philosopher, or, Great Britain's Wonder"],
#  [2057, 'The Last of the Plainsmen'],
#  [2058, 'Messer Marco Polo'],
#  [2059, 'The Little Shepherd of Kingdom Come'],
#  [2063, 'The Trail of the White Mule'],
#  [2065, "Dick Hamilton's Airship; Or, A Young Millionaire in the Clouds"],
#  [2066, 'Wildfire'],
#  [2068, 'Keziah Coffin'],
#  [2070, 'To the Last Man'],
#  [2072, 'Michael'],
#  [2075, 'Crotchet Castle'],
#  [2077, 'The Nabob'],
#  [2078, 'Thais'],
#  [2079, 'From the Memoirs of a Minister of France'],
#  [2081, 'The Blithedale Romance'],
#  [2084, 'The Way of All Flesh'],
#  [2085, 'Cyropaedia: The Education of Cyrus'],
#  [2086, 'The Slowcoach'],
#  [2090, 'Peach Blossom Shangri-la: Tao Hua Yuan Ji'],
#  [2095, 'Clotelle: A Tale of the Southern States'],
#  [2097, 'The Sign of the Four'],
#  [2098, "A Thief in the Night: A Book of Raffles' Adventures"],
#  [2123, 'The Crime of Sylvestre Bonnard'],
#  [2126, 'The Quest of the Sacred Slipper'],
#  [2127, 'Paul and Virginia'],
#  [2129, 'Murad the Unlucky, and Other Tales'],
#  [2132, 'The Daughter of an Empress'],
#  [2135, 'Stories by English Authors: London (Selected by Scribners)'],
#  [2138, "The Day's Work - Part 01"],
#  [2141, 'Strictly Business: More Stories of the Four Million'],
#  [2142, 'Childhood'],
#  [2145, 'Ben-Hur; a tale of the Christ'],
#  [2147, 'The Works of Edgar Allan Poe — Volume 1'],
#  [2148, 'The Works of Edgar Allan Poe — Volume 2'],
#  [2149, 'The Works of Edgar Allan Poe — Volume 3'],
#  [2150, 'The Works of Edgar Allan Poe — Volume 4'],
#  [2151, 'The Works of Edgar Allan Poe — Volume 5'],
#  [2152, 'On the Makaloa Mat/Island Tales'],
#  [2153, 'Mary Barton'],
#  [2154, 'Around the World in Eighty Days. Junior Deluxe Edition'],
#  [2155, 'Phyllis of Philistia'],
#  [2158, 'The Prime Minister'],
#  [2160, 'The Expedition of Humphry Clinker'],
#  [2163, 'The Bridge-Builders'],
#  [2164, 'The Lumley Autograph'],
#  [2165, 'The Lifted Veil'],
#  [2166, "King Solomon's Mines"],
#  [2171, 'Brother Jacob'],
#  [2172, 'That Mainwaring Affair'],
#  [2177, 'Thankful Blossom'],
#  [2178, 'By Shore and Sedge'],
#  [2179, 'Drift from Two Shores'],
#  [2180, 'In a Hollow of the Hills'],
#  [2181, 'The Marble Faun; Or, The Romance of Monte Beni - Volume 1'],
#  [2182, 'The Marble Faun; Or, The Romance of Monte Beni - Volume 2'],
#  [2183, 'Three Men on the Bummel'],
#  [2185, 'Maruja'],
#  [2186, '"Captains Courageous": A Story of the Grand Banks'],
#  [2188, 'Die Aufzeichnungen des Malte Laurids Brigge'],
#  [2190, 'Isabella von Ägypten: Kaiser Karl des Fünften erste Jugendliebe'],
#  [2191, 'Boy Scouts in Mexico; Or, On Guard with Uncle Sam'],
#  [2192, 'The Dark Flower'],
#  [2193, 'A Ward of the Golden Gate'],
#  [2194, 'Mauprat'],
#  [2196, 'An Iceland Fisherman'],
#  [2197, 'The Gambler'],
#  [2225, '"Captains Courageous": A Story of the Grand Banks'],
#  [2227, 'Soldiers Three - Part 2'],
#  [2231, 'All Roads Lead to Calvary'],
#  [2233, 'A Damsel in Distress'],
#  [2234, 'Sketches in Lavender, Blue and Green'],
#  [2271, 'He Fell in Love with His Wife'],
#  [2273, 'Tom Swift and His Motor-Boat; Or, The Rivals of Lake Carlopa'],
#  [2275, 'The Pioneers; Or, The Sources of the Susquehanna'],
#  [2276, 'The Private Memoirs and Confessions of a Justified Sinner'],
#  [2279, 'A Waif of the Plains'],
#  [2280, 'A Millionaire of Rough-and-Ready'],
#  [2281, 'The Heritage of Dedlow Marsh and Other Tales'],
#  [2283, 'The Lost Road'],
#  [2284, 'Animal Heroes'],
#  [2285,
#   'Ridgway of Montana (Story of To-Day, in Which the Hero Is Also the '
#   'Villain)'],
#  [2286, "Devil's Ford"],
#  [2287, 'Havoc'],
#  [2288, 'Through Russia'],
#  [2291, 'David Elginbrod'],
#  [2295, 'Waifs and Strays'],
#  [2297, "Snow-Bound at Eagle's"],
#  [2299, 'Pandora'],
#  [2301, 'A Simpleton'],
#  [2302, 'Poor Folk'],
#  [2305, 'A Set of Six'],
#  [2307, 'The Depot Master'],
#  [2309, 'The Freelands'],
#  [2310, 'In the Carquinez Woods'],
#  [2313, 'Geschichte des Agathon. Teil 1'],
#  [2314, 'Geschichte des Agathon. Teil 2'],
#  [2315, 'The Flag-Raising'],
#  [2316, 'The Choir Invisible'],
#  [2318, 'Droll Stories — Volume 2'],
#  [2320, 'Novelle'],
#  [2324, 'A House to Let'],
#  [2325, 'The Iceberg Express'],
#  [2326, 'His Own People'],
#  [2327, 'Some Short Stories [by Henry James]'],
#  [2328, 'The Lake Gun'],
#  [2329, 'Autobiography of a Pocket-Handkerchief'],
#  [2334, 'The Works of Rudyard Kipling: One Volume Edition'],
#  [2335, 'Wilhelm Meisters Lehrjahre — Band 1'],
#  [2336, 'Wilhelm Meisters Lehrjahre — Band 2'],
#  [2337, 'Wilhelm Meisters Lehrjahre — Band 3'],
#  [2338, 'Wilhelm Meisters Lehrjahre — Band 4'],
#  [2339, 'Wilhelm Meisters Lehrjahre — Band 5'],
#  [2343, 'The Adventure of Wisteria Lodge'],
#  [2344, 'The Adventure of the Cardboard Box'],
#  [2345, 'The Adventure of the Red Circle'],
#  [2346, 'The Adventure of the Bruce-Partington Plans'],
#  [2347, 'The Adventure of the Dying Detective'],
#  [2348, 'The Disappearance of Lady Frances Carfax'],
#  [2349, "The Adventure of the Devil's Foot"],
#  [2350, 'His Last Bow'],
#  [2351, 'John Halifax, Gentleman'],
#  [2353, 'Tea-Table Talk'],
#  [2356, 'Tommy and Co.'],
#  [2357, 'Great Jehoshaphat and Gully Dirt!'],
#  [2358, 'The After House'],
#  [2359, 'Stories By English Authors: France (Selected by Scribners)'],
#  [2360, 'The Riddle of the Sands'],
#  [2363, "Incognita; Or, Love and Duty Reconcil'd"],
#  [2364, 'Active Service'],
#  [2365, 'The Princess De Montpensier'],
#  [2366, 'The Beldonald Holbein'],
#  [2368, 'The Angel and the Author, and Others'],
#  [2369, 'One of Ours'],
#  [2370, 'Sir Gibbie'],
#  [2372, 'The Woman-Haters'],
#  [2374, 'Dora Thorne'],
#  [2375, 'Tartarin De Tarascon'],
#  [2377, 'The Son of the Wolf'],
#  [2384, 'The Deliverance: A Romance of the Virginia Tobacco Fields'],
#  [2387, 'The Voice'],
#  [2389, 'Bardelys the Magnificent'],
#  [2391, 'Bruce'],
#  [2392, 'Further Adventures of Lad'],
#  [2393, 'His Dog'],
#  [2399, 'Imaginary Portraits'],
#  [2403, 'Die Wahlverwandtschaften'],
#  [2407, 'Die Leiden des jungen Werther — Band 1'],
#  [2408, 'Die Leiden des jungen Werther — Band 2'],
#  [2409, 'Wilhelm Meisters Wanderjahre — Band 1'],
#  [2410, 'Wilhelm Meisters Wanderjahre — Band 2'],
#  [2413, 'Madame Bovary'],
#  [2415, 'The Mutiny of the Elsinore'],
#  [2416, 'The House of Pride, and Other Tales of Hawaii'],
#  [2417, 'Okewood of the Secret Service'],
#  [2419, 'La dame aux camélias'],
#  [2424, "Black Bartlemy's Treasure"],
#  [2425, 'A Bundle of Letters'],
#  [2426, 'The Diary of a Man of Fifty'],
#  [2427, 'The Patagonia'],
#  [2429, 'Lost Face'],
#  [2432, 'Barchester Towers'],
#  [2433, 'Donal Grant'],
#  [2436, 'The Marriages'],
#  [2437, 'They and I'],
#  [2438, 'Daphne: An Autumn Pastoral'],
#  [2442,
#   'History of the Impeachment of Andrew Johnson, President of the United '
#   'States, by the House of Representatives, and his trial by the Senate for '
#   'high crimes and misdemeanors in office, 1868'],
#  [2450, 'Boyhood'],
#  [2451, 'Caught in the Net'],
#  [2452, 'Shavings: A Novel'],
#  [2453, 'Beyond'],
#  [2454, 'The Silent Bullet'],
#  [2457, 'Stories By English Authors: Italy (Selected by Scribners)'],
#  [2459, "Trent's Trust, and Other Stories"],
#  [2460, 'The Madonna of the Future'],
#  [2461, 'The Lady of Lyons; Or, Love and Pride'],
#  [2462, 'Dona Perfecta'],
#  [2463, 'The Prophet of Berkeley Square'],
#  [2465, 'Carmen'],
#  [2466, 'Virgin Soil'],
#  [2470, 'Samuel Brohl and Company'],
#  [2472, 'White Lies'],
#  [2473, "Mary-'Gusta"],
#  [2474,
#   'The Circus Boys on the Flying Rings; Or, Making the Start in the Sawdust '
#   'Life'],
#  [2475,
#   'The Circus Boys Across the Continent; Or, Winning New Laurels on the '
#   'Tanbark'],
#  [2476,
#   'The Circus Boys in Dixie Land; Or, Winning the Plaudits of the Sunny South'],
#  [2477,
#   'The Circus Boys on the Mississippi; Or, Afloat with the Big Show on the Big '
#   'River'],
#  [2478,
#   'The Circus Boys on the Plains; Or, The Young Advance Agents Ahead of the '
#   'Show'],
#  [2480, 'Under Western Eyes'],
#  [2483, 'Janice Day, the Young Homemaker'],
#  [2486, 'Queer Little Folks'],
#  [2488,
#   'Twenty Thousand Leagues Under the Seas: An Underwater Tour of the World'],
#  [2489, 'Moby Dick; Or, The Whale'],
#  [2492, 'Orpheus in Mayfair, and Other Stories and Sketches'],
#  [2493, 'The Adventures of Paddy Beaver'],
#  [2495, 'Susy, a Story of the Plains'],
#  [2496, 'Our Village'],
#  [2497, 'Put Yourself in His Place'],
#  [2499, 'Siddhartha: eine indische Dichtung'],
#  [2500, 'Siddhartha'],
#  [2501, 'A Face Illumined'],
#  [2505, 'The Heir of Redclyffe'],
#  [2508, 'Stories in Light and Shadow'],
#  [2509, 'The Lani People'],
#  [2511, 'The History of Henry Esmond, Esq.'],
#  [2514, 'T. Tembarom'],
#  [2515, 'Stepping Heavenward'],
#  [2516, 'Redgauntlet: A Tale Of The Eighteenth Century'],
#  [2518, 'The Hungry Stones, and Other Stories'],
#  [2520, 'The Man'],
#  [2521, 'Lizzie Leigh'],
#  [2522, "A Dark Night's Work"],
#  [2524, 'My Lady Ludlow'],
#  [2525, 'John Ingerfield, and Other Stories'],
#  [2527, 'The Sorrows of Young Werther'],
#  [2532, 'The Half-Brothers'],
#  [2533, 'Round the Sofa'],
#  [2534, 'Eugene Pickering'],
#  [2535, 'Openings in the Old Trail'],
#  [2538, 'Poems and Tales from Romania'],
#  [2544, 'From Sand Hill to Pine'],
#  [2545, 'When God Laughs, and Other Stories'],
#  [2546, "Hopalong Cassidy's Rustler Round-Up; Or, Bar-20"],
#  [2547, 'Half a Life-Time Ago'],
#  [2548, 'The Poor Clare'],
#  [2549, 'The Doom of the Griffiths'],
#  [2550, 'Tales of Trail and Town'],
#  [2551, 'Droll Stories — Volume 3'],
#  [2552, "Thankful's Inheritance"],
#  [2554, 'Crime and Punishment'],
#  [2555, 'Under the Redwoods'],
#  [2556, "Mr. Jack Hamlin's Mediation"],
#  [2557, 'Old Mother West Wind'],
#  [2559, 'The Forsyte Saga, Volume I.'],
#  [2560, 'The Three Partners'],
#  [2561, 'Robert Falconer'],
#  [2565, 'The Story of the Glittering Plain'],
#  [2568, "Trent's Last Case"],
#  [2569, "The Day's Work - Volume 1"],
#  [2573, 'The Caged Lion'],
#  [2574, 'On the Frontier'],
#  [2590, 'Guy Mannering'],
#  [2594, 'The Forsyte Saga, Volume II.'],
#  [2595, 'Ramsey Milholland'],
#  [2596, 'The Forsyte Saga, Volume III.'],
#  [2597, "Mrs. Skagg's Husbands and Other Stories"],
#  [2598, 'Urban Sketches'],
#  [2599, 'Legends and Tales'],
#  [2600, 'War and Peace'],
#  [2601, "Heartsease; Or, The Brother's Wife"],
#  [2602, "Queen Sheba's Ring"],
#  [2604, 'The Longest Journey'],
#  [2606, 'The Pigeon Pie'],
#  [2609, 'The Vicomte de Bragelonne'],
#  [2610, 'Notre-Dame De Paris'],
#  [2618, 'A House-Boat on the Styx'],
#  [2635, 'Clarence'],
#  [2636, "The Historical Nights' Entertainment: First Series"],
#  [2637, 'Youth'],
#  [2638, 'The Idiot'],
#  [2639, 'Villa Rubein, and Other Stories'],
#  [2640, "St. Martin's Summer"],
#  [2641, 'A Room with a View'],
#  [2642, 'Back Home'],
#  [2650, 'Du côté de chez Swann'],
#  [2661, 'The Story of a Mine'],
#  [2662, 'Under the Greenwood Tree'],
#  [2664, 'Zanoni'],
#  [2665, 'The Professor at the Breakfast-Table'],
#  [2666, 'The Poet at the Breakfast-Table'],
#  [2667, 'The Vicar of Wakefield'],
#  [2675, 'Burlesques'],
#  [2676, "The Bell-Ringer of Angel's, and Other Stories"],
#  [2681, 'Ten Years Later'],
#  [2683, "Saint's Progress"],
#  [2684, 'Five Tales'],
#  [2685, 'The Way to Peace'],
#  [2687, 'The Snare'],
#  [2691, "Nan Sherwood at Pine Camp; Or, The Old Lumberman's Secret"],
#  [2692, "A Protegee of Jack Hamlin's, and Other Stories"],
#  [2693, 'Greyfriars Bobby'],
#  [2694, 'I and my Chimney'],
#  [2695, "Jeff Briggs's Love Story"],
#  [2696, 'Elsie Venner'],
#  [2697, 'The Guardian Angel'],
#  [2698, 'A Mortal Antipathy'],
#  [2701, 'Moby Dick; Or, The Whale'],
#  [2702, "The Lion's Skin"],
#  [2703, 'The Argonauts of North Liberty'],
#  [2705, 'Sally Dows'],
#  [2706, 'The Bravo of Venice: A Romance'],
#  [2708, 'Colomba'],
#  [2709, 'The Man Who Was Afraid'],
#  [2710, 'Louise de la Valliere'],
#  [2711, 'A Phyllis of the Sierras'],
#  [2712, 'A Drift from Redwood Camp'],
#  [2713, "Maiwa's Revenge; Or, The War of the Little Hand"],
#  [2714, 'Long Live the King!'],
#  [2715, 'The Real Thing'],
#  [2716, 'Sir Dominick Ferrand'],
#  [2717, 'Nona Vincent'],
#  [2718, 'The Chaperon'],
#  [2719, 'Greville Fane'],
#  [2720, 'The Pension Beaurepas'],
#  [2721, 'Eric Brighteyes'],
#  [2722, 'Morning Star'],
#  [2723, 'A First Family of Tasajara'],
#  [2725, 'Red Pepper Burns'],
# ...
#  [33943, 'Woman'],
#  [33945, 'The Unknown Sea'],
#  [33947, 'The Nerve of Foley, and Other Railroad Stories'],
#  [33948, 'The Hollow Tree Snowed-in Book'],
#  [33958, "A Sister's Love: A Novel"],
#  [33959, 'The Reclaimers'],
#  [33963, 'The Valiants of Virginia'],
#  [33964, 'The Man Who Rose Again'],
#  [33968, 'Tales from "Blackwood," Volume 3'],
#  [33969, 'New Hire'],
#  [33970, 'The Raid of The Guerilla, and Other Stories'],
#  [33971, 'Witching Hill'],
#  [33973, 'The Mysterious Wanderer, Vol. I'],
#  [33976, 'Jane, Stewardess of the Air Lines'],
#  [33977, "Miss Million's Maid: A Romance of Love and Fortune"],
#  [33980, 'In Story-land'],
#  [33981, 'Eene schitterende "carrière"'],
#  [33984, 'The Man from Jericho'],
#  [33985, 'Manslaughter'],
#  [33989, 'Love Works Wonders: A Novel'],
#  [33990, 'The Red Cross Girls with Pershing to Victory'],
#  [33993, 'Onder de koppensnellers op Borneo'],
#  [33995, 'Where the Path Breaks'],
#  [33996, 'The Spy in Black'],
#  [33999, 'The Bondman: A New Saga'],
#  [34000, 'Rachel Ray'],
#  [34002, "Dick's Desertion: A Boy's Adventures in Canadian Forests"],
#  [34003, 'Left on the Prairie'],
#  [34009, 'Stranded in Arcady'],
#  [34017, 'Deep Moat Grange'],
#  [34020, 'The Window at the White Cat'],
#  [34035, 'The Hillman'],
#  [34045, 'A Christmas Child'],
#  [34046, 'Whispering Wires'],
#  [34053, 'The Palace of Pleasure, Volume 2'],
#  [34058, 'The Crime of the Boulevard'],
#  [34064, 'Der Courier des Czaar (Michael Strogoff)'],
#  [34079, "Tajemnica Baskerville'ów: dziwne przygody Sherlocka Holmes"],
#  [34144, "Wilson's Tales of the Borders and of Scotland, Volume 04"],
#  [34145, "Wilson's Tales of the Borders and of Scotland, Volume 05"],
#  [34146, "Wilson's Tales of the Borders and of Scotland, Volume 07"],
#  [34147, "Wilson's Tales of the Borders and of Scotland, Volume 08"],
#  [34148, "Wilson's Tales of the Borders and of Scotland, Volume 10"],
#  [34149, "Wilson's Tales of the Borders and of Scotland, Volume 12"],
#  [34150, "Wilson's Tales of the Borders and of Scotland, Volume 13"],
#  [34151, "Wilson's Tales of the Borders and of Scotland, Volume 14"],
#  [34152, "Wilson's Tales of the Borders and of Scotland, Volume 15"],
#  [34153, "Wilson's Tales of the Borders and of Scotland, Volume 16"],
#  [34215, 'Shadowings'],
#  [34219, 'The Enchanted Castle'],
#  [34225, 'Zápisky z mrtvého domu'],
#  [34241, 'Kenelm Chillingly: Hänen elämänvaiheensa ja mielipiteensä'],
#  [34284, 'The Wood Fire in No. 3'],
#  [34296, 'Ross Grant, Tenderfoot'],
#  [34297, "Angela's Business"],
#  [34301, 'Le Bossu Volume 3'],
#  [34317, 'Caribbee'],
#  [34322, 'The Moghul'],
#  [34323, 'The Samurai Strategy'],
#  [34332, 'Ivanhoe (2/4)'],
#  [34339, 'The Princess and the Goblin'],
#  [34342, 'Ivanhoe (3/4)'],
#  [34345, 'Pride'],
#  [34347,
#   'Dave Porter in the South Seas; or, The Strange Cruise of the Stormy Petrel'],
#  [34354, 'Le Bossu Volume 4'],
#  [34369, 'Penny Nichols and the Mystery of the Lost Key'],
#  [34395, 'Ghost Beyond the Gate'],
#  [34403, 'The Clock Strikes Thirteen'],
#  [34414, 'Just William'],
#  [34420, "Riya's Foundling"],
#  [34441, 'The Cry at Midnight'],
#  [34443, "The Camp Fire Girls at the Seashore; Or, Bessie King's Happiness"],
#  [34467, 'In Camp With A Tin Soldier'],
#  [34535,
#   "Digby Heathcote: The Early Days of a Country Gentleman's Son and Heir"],
#  [34552, 'Danger at the Drawbridge'],
#  [34553, 'Over the Plum Pudding'],
#  [34559, 'Le Bossu Volume 5'],
#  [34591, 'Clue of the Silken Ladder'],
#  [34592, 'Behind the Green Door'],
#  [34608, 'Ivanhoe (4/4)'],
#  [34627, 'The Dealings of Captain Sharkey'],
#  [34629, 'The Mysterious Wanderer; Vol. II'],
#  [34630, 'Some Experiences of an Irish R.M.'],
#  [34689, 'The Wishing Well'],
#  [34691, 'Hoofbeats on the Turnpike'],
#  [34732, 'Max Carrados'],
#  [34754, 'The Orpheus C. Kerr Papers, Series 2'],
#  [34766, 'Shorter Novels, Eighteenth Century'],
#  [34797, 'The Man from Archangel'],
#  [34805, "Betty's Battles"],
#  [34810, 'The Red Miriok'],
#  [34817, 'Tales of the Wonder Club, Volume II'],
#  [34831, 'Guilt of the Brass Thieves'],
#  [34832, 'Voice from the Cave'],
#  [34840, 'The Palace of Pleasure, Volume 3'],
#  [34850, 'Signal in the Dark'],
#  [34858, 'The Ordeal of Richard Feverel: A History of a Father and Son'],
#  [34886, 'St. George for England: A Tale of Cressy and Poitiers'],
#  [34899, 'Berend Veltink'],
#  [34905, 'The Pobratim: A Slav Novel'],
#  [34916, 'The Chainbearer; Or, The Littlepage Manuscripts'],
#  [34922, 'A History of Pendennis, Volume 1'],
#  [34927, 'The Ranch Girls and Their Great Adventure'],
#  [34928, 'The Ranch Girls at Home Again'],
#  [34929, 'The Ranch Girls in Europe'],
#  [34975, 'Whispering Walls'],
#  [35007, 'Vineta'],
#  [35034, 'Lost Farm Camp'],
#  [35064, 'Anatole, Vol. 1'],
#  [35082, 'Saboteurs on the River'],
#  [35083, 'Swamp Island'],
#  [35103, 'La Vie Électrique'],
#  [35129, 'Anatole, Vol. 2'],
#  [35161, 'Tales from Spenser; Chosen from the Faerie Queene'],
#  [35178, 'Ben Pepper'],
#  [35201, 'Clear the Track! A Story of To-day'],
#  [35247, 'That Affair at Elizabeth'],
#  [35281, 'The Joyous Story of Toto'],
#  [35304, 'The Last Stroke'],
#  [35362, 'Billy Barcroft, R.N.A.S.: A Story of the Great War'],
#  [35378, 'The Strength of the Pines'],
#  [35404, 'Les petites filles modèles'],
#  [35425, 'The Mad Planet'],
#  [35464, 'Tales from "Blackwood," Volume 4'],
#  [35499, 'The Pharaoh and the Priest: An Historical Novel of Ancient Egypt'],
#  [35552, 'Tales from "Blackwood," Volume 5'],
#  [35560, 'Quo Vadis (Πού πηγαίνεις): Μυθιστόρημα της Νερωνικής Εποχής'],
#  [35574, 'Seeing France with Uncle John'],
#  [35594, 'The Radio Boys at Ocean Point; Or, The Message that Saved the Ship'],
#  [35644, 'The Taming of the Jungle'],
#  [35649, 'The Lost Mountain'],
#  [35759, 'Security Risk'],
#  [35770, 'The Hero'],
#  [35788, 'Tales from "Blackwood," Volume 8'],
#  [35807, 'Non-combatants and Others'],
#  [35867, 'Tales from "Blackwood," Volume 9'],
#  [35906, 'The Orpheus C. Kerr Papers, Series 1'],
#  [35979, 'Le Bossu Volume 6'],
#  [35987, "The Radio Boys' Search for the Inca's Treasure"],
#  [35997, 'The Jungle Book'],
#  [36016, 'The Prussian Terror'],
#  [36102, 'A Princess of Mars'],
#  [36107, 'Trevethlan: A Cornish Story. Volume 2 (of 3)'],
#  [36108, 'Trevethlan: A Cornish Story. Volume 3 (of 3)'],
#  [36122, 'The Winning of the Golden Spurs'],
#  [36273, 'The Automobile Girls at Newport'],
#  [36309, 'The Water-Babies'],
#  [36314, 'The Radio Boys Rescue the Lost Alaska Expedition'],
#  [36378, 'Ancient Manners; Also Known As Aphrodite'],
#  [36391,
#   'The Meadow-Brook Girls Across Country; Or, The Young Pathfinders on a '
#   'Summer Hike'],
#  [36396, 'Ruth Fielding In the Saddle'],
#  [36406, 'Mercedes of Castile; Or, The Voyage to Cathay'],
#  [36424, 'Army Boys in France; or, From Training Camp to Trenches'],
#  [36429, "Randy's Summer: A Story for Girls"],
#  [36437, 'Le mari de madame de Solange'],
#  [36499, 'Rounding up the Raider: A Naval Story of the Great War'],
#  [36500,
#   'The Dispatch-Riders: The Adventures of Two British Motor-cyclists in the '
#   'Great War'],
#  [36573, 'La aldea perdida'],
#  [36588, 'The Red Derelict'],
#  [36592, 'The Fire Trumpet: A Romance of the Cape Frontier'],
#  [36593, "Fordham's Feud"],
#  [36599, 'Golden Face: A Tale of the Wild West'],
#  [36605, "The Sirdar's Oath: A Tale of the North-West Frontier"],
#  [36606, 'The Ruby Sword: A Romance of Baluchistan'],
#  [36623, 'Dorrien of Cranston'],
#  [36641, "Women Novelists of Queen Victoria's Reign: A Book of Appreciations"],
#  [36686, 'The Vicar of Wrexhill'],
#  [36731, 'Tales of the Wonder Club, Volume III'],
#  [36740, 'Peggy Owen, Patriot: A Story for Girls'],
#  [36744, 'Peggy Owen at Yorktown'],
#  [36812, 'Création et rédemption'],
#  [36827, 'The Vulture Maiden'],
#  [36867, 'Progress Report'],
#  [36940, 'El señorito Octavio'],
#  [37217, "Wilson's Tales of the Borders and of Scotland, Volume 20"],
#  [37271, "The Ranch Girls and Their Heart's Desire"],
#  [37324, 'Mrs. Bindle: Some Incidents from the Domestic Life of the Bindles'],
#  [37332,
#   'A Little Princess: Being the whole story of Sara Crewe now told for the '
#   'first time'],
#  [37336, "Wilson's Tales of the Borders and of Scotland, Volume 21"],
#  [37339, "'Midst the Wild Carpathians"],
#  [37364, 'The Second Jungle Book'],
#  [37448, "Comet's Burial"],
#  [37454, 'The Automobile Girls Along the Hudson'],
#  [37466, 'Lost in the Cañon'],
#  [37581, 'The Cricket on the Hearth'],
#  [37600, 'The Fight for Constantinople: A Story of the Gallipoli Peninsula'],
#  [37624, 'Count Brühl'],
#  [37637, 'Los majos de Cádiz'],
#  [37652, 'The Nameless Island: A Story of some Modern Robinson Crusoes'],
#  [37653, 'Sentiment, Inc.'],
#  [37723, 'For Sceptre and Crown, Vol. I (of II)'],
#  [37724, 'For Sceptre and Crown, Vol. II (of II)'],
#  [37766, 'Strange Stories from the Lodge of Leisures'],
#  [37820, 'Chronicles of Martin Hewitt'],
#  [37824, 'The Wireless Officer'],
#  [37885, 'Kolme muskettisoturia'],
#  [37911, 'The Motor Girls at Lookout Beach; Or, In Quest of the Runaways'],
#  [37969, 'The Marquis of Peñalta (Marta y María): A Realistic Social Novel'],
#  [38123, 'The Automobile Girls at Palm Beach'],
#  [38169, 'The Heath Hover Mystery'],
#  [38222,
#   "The Quest of the 'Golden Hope': A Seventeenth Century Story of Adventure"],
#  [38234, 'Hopalong Cassidy'],
#  [38241, "Uncle's Dream; and The Permanent Husband"],
#  [38287, "We're Civilized!"],
#  [38316, 'Le Chevalier des Touches'],
#  [38421, 'A Little Boy Lost'],
#  [38449, 'Het Stoomhuis: De Waanzinnige der Nerbudda (2/2)'],
#  [38451, 'Tahiti: Roman aus der Südsee. Dritter Band.'],
#  [38453,
#   'The Radio Boys at Mountain Pass; Or, The Midnight Call for Assistance'],
#  [38523, "The Noank's Log"],
#  [38603, 'The Lost Gold of the Montezumas'],
#  [38667, 'De kinderen van Kapitein Grant, eerste deel (van 3)'],
#  [38668, 'De kinderen van Kapitein Grant, tweede deel (van 3)'],
#  [38669, 'De kinderen van Kapitein Grant, derde deel (van 3)'],
#  [38674, 'De la terre à la lune'],
#  [38714, 'Carry On! A Story of the Fight for Bagdad'],
#  [38814, 'La novela de un novelista'],
#  [38896, 'The Hollow Tree Snowed-in Book'],
#  [38996, 'Dix contes modernes des meilleurs auteurs du jour'],
#  [39057, 'Kapteeni Grantia etsimässä'],
#  [39058, 'Kapteeni Grantin lapset'],
#  [39059, 'Kapteeni Grantin löytyminen'],
#  [39102, "The Auto Boys' Quest"],
#  [39128, 'Kensington Rhymes'],
#  [39150, 'A Hero of Liége: A Story of the Great War'],
#  [39209, 'Platero y yo'],
#  [39270, 'The Life and Opinions of Tristram Shandy, Gentleman'],
#  [39311, 'Les mystères du peuple, Tome V'],
#  [39425, 'The Mysterious Wanderer, Vol. III'],
#  [39444, 'Páginas escogidas'],
#  [39488, 'The Airship "Golden Hind"'],
#  [39489, 'With Beatty off Jutland: A Romance of the Great Sea Fight'],
#  [39490,
#   'A Lad of Grit: A Story of Adventure on Land and Sea in Restoration Times'],
#  [39547, 'Beaumaroy Home from the Wars'],
#  [39552, "Mortomley's Estate, Vol. II (of 3)"],
#  [39558, "Mrs. Tree's Will"],
#  [39570, "Polly's First Year at Boarding School"],
#  [39611, "Mortomley's Estate, Vol. I (of 3)"],
#  [39661, "Mortomley's Estate, Vol. III (of 3)"],
#  [39667, 'Vier Jahre Politischer Mord'],
#  [39759, "Wilson's Tales of the Borders and of Scotland, Volume 18"],
#  [39801, 'Fighting with French: A Tale of the New Army'],
#  [39835, 'Les morts commandent'],
#  [39868, 'Glinda of Oz'],
#  [39912, "Tom Willoughby's Scouts: A Story of the War in German East Africa"],
#  [39923, 'The Lucky Seventh'],
#  [40017, 'The Stampeder'],
#  [40073,
#   'A Lively Bit of the Front: A Tale of the New Zealand Rifles on the Western '
#   'Front'],
#  [40300, 'Dorothy'],
#  [40368, 'An Annapolis First Classman'],
#  [40410, 'Dickens and His Illustrators'],
#  [40557, 'Kvinnlighet och erotik I.'],
#  [40602, 'The Freebooters: A Story of the Texan War'],
#  [40660, 'The Interpreter: A Tale of the War'],
#  [40723, 'The Battle of Life'],
#  [40745, 'Short Stories'],
#  [40866, 'The Rival Submarines'],
#  [40953, 'A Traveler in Time'],
#  [40954, 'Potential Enemy'],
#  [40961, 'Luna Escapade'],
#  [40964, 'Tony and the Beetles'],
#  [40968, 'Desire No More'],
#  [40969, 'The Mating of the Moons'],
#  [40970, "Exploiter's End"],
#  [40991, 'The Butterfly Kiss'],
#  [40992, 'The Martian'],
#  [40993, 'Spacewrecked on Venus'],
#  [41027, 'The Revolt of the Star Men'],
#  [41029, 'The Moon Destroyers'],
#  [41049, 'The Onslaught from Rigel'],
#  [41062, 'The Final Figure'],
#  [41064, 'The Chapter Ends'],
#  [41084, 'The Metal Moon'],
#  [41117, 'Dorothy at Skyrie'],
#  [41119, 'A Russian Proprietor, and Other Stories'],
#  [41193, 'Työmiehiä: Romaani'],
#  [41204, 'Tales from "Blackwood," Volume 6'],
#  [41247, 'Ten Thousand a-Year. Volume 3.'],
#  [41301, 'Kvinnlighet och erotik II.'],
#  [41303, 'A Ladder of Swords: A Tale of Love, Laughter and Tears'],
#  [41332, 'Ten Thousand a-Year. Volume 2.'],
#  [41408, 'Affinities, and Other Stories'],
#  [41410,
#   "Dick Hamilton's Football Team; Or, A Young Millionaire On The Gridiron"],
#  [41438, 'The Heart of Princess Osra'],
#  [41445, 'Frankenstein; Or, The Modern Prometheus'],
#  [41481, 'Astounding Stories of Super-Science January 1930'],
#  [41529,
#   'Tales from the X-bar Horse Camp: The Blue-Roan "Outlaw" and Other Stories'],
#  [41562, 'The Hanging Stranger'],
#  [41565, 'Consignment'],
#  [41585, 'Amerikanische Wald- und Strombilder. Zweiter Band.'],
#  [41586, 'The Red Dust'],
#  [41622, 'Futuria Fantasia, Summer 1939'],
#  [41624, 'Futuria Fantasia, Fall 1939'],
#  [41627, 'Futuria Fantasia, Winter 1940'],
#  [41637, 'The Forgotten Planet'],
#  [41651, 'Futuria Fantasia, Spring 1940'],
#  [41659, 'The Swiss Family Robinson: A Translation from the Original German'],
#  [41667, 'The Emerald City of Oz'],
#  [41670, 'Carinus; A nagyenyedi két fűzfa'],
#  [41714, 'The Syndic'],
#  [41715, 'Dave Dawson with the R.A.F.'],
#  [41718, 'Dave Dawson on the Russian Front'],
#  [41737, 'Burton of the Flying Corps'],
#  [41746, 'Flor de mayo'],
#  [41753, 'Dave Dawson at Truk'],
#  [41905, 'Captives of the Flame'],
#  [41962, 'Law of the North (Originally published as Empery)'],
#  [41981, 'The Jewels of Aptor'],
#  [41984, 'Les Immémoriaux'],
#  [42014, 'Meg of Mystery Mountain'],
#  [42111, 'And Then the Town Took Off'],
#  [42133, 'Bobs, a Girl Detective'],
#  [42182, 'The Hyborian Age'],
#  [42183, 'Queen of the Black Coast'],
#  [42188, 'Shadows in the Moonlight'],
#  [42196, 'Shadows in Zamboula'],
#  [42209, 'The Devil in Iron'],
#  [42227, 'A Witch Shall Be Born'],
#  [42236, 'Jewels of Gwahlur'],
#  [42243, 'The Hour of the Dragon'],
#  [42250, 'Dave Dawson with the Commandos'],
#  [42254, 'Beyond the Black River'],
#  [42259, 'The People of the Black Circle'],
#  [42324, 'Frankenstein; Or, The Modern Prometheus'],
#  [42544, "Soyer's Culinary Campaign"],
#  [42664, 'Gods of the North'],
#  [42672, 'The wanderings and fortunes of some German emigrants'],
#  [42689, 'The Young Cavalier: A Story of the Civil Wars'],
#  [42802, 'The Riddle of the Mysterious Light'],
#  [42901, 'Creatures of the Abyss'],
#  [42914, 'Gladiator'],
#  [42919, 'Angel Unawares: A Story of Christmas Eve'],
#  [42943, 'Frank Forester: A Story of the Dardanelles'],
#  [42987, 'Nightmare Planet'],
#  [43038, 'Ripeness is All'],
#  [43041, 'Double or Nothing'],
#  [43046, 'Planet of Dread'],
#  [43048, 'The Piebald Hippogriff'],
#  [43110, 'Tell Me a Story'],
#  [43135, 'The Riddle of the Purple Emperor'],
#  [43215, 'Ivanhoe'],
#  [43235, 'First on the Moon'],
#  [43264, 'The Phantom Airman'],
#  [43265, "Under Wolfe's Flag; or, The Fight for the Canadas"],
#  [43344, 'Don Hale with the Flying Squadron'],
#  [43438, 'Erotika Biblion'],
#  [43741,
#   'Old Friends and New Fancies: An Imaginary Sequel to the Novels of Jane '
#   'Austen'],
#  [44074, 'Meccania'],
#  [44107, 'The Growth of a Soul'],
#  [44304, 'The Deserter, and Other Stories: A Book of Two Wars'],
#  [44348, 'Dastral of the Flying Corps'],
#  [44487, 'Captured at Tripoli: A Tale of Adventure'],
#  [44592, 'Light for Little Ones'],
#  [44632, "Hell's Hatches"],
#  [44879, 'Up Terrapin River'],
#  [44979, 'The Secret Memoirs of Bertha Krupp'],
#  [45135, 'The Thick of the Fray at Zeebrugge, April 1918'],
#  [45644, 'Guirlanden um Die Urnen der Zukunft'],
#  [45727,
#   'The Boy Aviators with the Air Raiders: A Story of the Great World War'],
#  [45960, 'A Naval Venture: The War Story of an Armoured Cruiser'],
#  [46549, 'The Willing Horse: A Novel']]
